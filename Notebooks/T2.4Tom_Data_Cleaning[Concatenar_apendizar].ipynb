# %% [markdown]
# # Unir dos datasets (uno debajo del otro)

# %%
import pandas as pd
import os

# %%
mainpath = "F:/BD/GitHub/mlearningcourse/datasets/"
rwine = "wine/winequality-red.csv"
wwine = "wine/winequality-white.csv"
# Option 1
# fullpath = mainpath + titanic3 
# Option 2
redwine =os.path.join(mainpath,rwine)
whitewine = os.path.join(mainpath,wwine)

# %%
red_wine =pd.read_csv(redwine, sep = ';')
red_wine.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5

# %%
red_wine.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
red_wine.columns.values == red_wine.columns.values
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
white_wine =pd.read_csv(whitewine, sep = ';') 
white_wine.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
#
#    alcohol  quality
# 0      8.8        6

# %%
white_wine.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
white_wine.shape
# Out:
# (4898, 12)

# %% [markdown]
# En python, tenemos dos tipos de ejes:
#   * axis = 0, denota el eje horizontal (filas)
#   * axis = 1, denota el eje vertical (columnas)

# %%
# Concatenar dos datasets (Se concatena en el orden en que se codifica)
wine_data = pd.concat([red_wine, white_wine], axis = 0)  #Primero el dataset del vino tinto, abajo el data set del vino blanco

# %%
# Forma del dataset
wine_data.shape
# Out:
# (6497, 12)

# %%
# Dataset total
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
#Ejemplo de Scramble (unir)
data1 = wine_data.head(10)
data2 = wine_data[300:310]
data3 = wine_data.tail(10)

# %%
wine_scramble = pd.concat ([data1, data2,data3], axis = 0)

# %%
# Apilado (uno encima del otro, de los tres datasets)
wine_scramble.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# Es posible cambiar el orden
wine_scramble = pd.concat ([data3, data2,data1], axis = 0)
wine_scramble.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4888                 38.0                 127.0  0.99330  3.04       0.54
# 4889                 34.0                 118.0  0.99540  3.07       0.50
# 4890                 25.0                 100.0  0.98938  3.06       0.44
# 4891                 38.0                 121.0  0.99074  3.24       0.46
# 4892                 29.0                 112.0  0.99298  3.29       0.54
#
#       alcohol  quality
# 4888      9.2        5
# 4889      9.4        6
# 4890     11.8        6
# 4891     10.6        6
# 4892      9.7        5

# %% [markdown]
# ### Segundo ejercicio de unión de tablas
# #### Consolidación de múltiples CSV

# %%
# Mirar el primer dataset

data = pd.read_csv('F:/BD/GitHub/mlearningcourse/datasets/distributed-data/001.csv')

# %%
data.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
data.shape
# Out:
# (1461, 4)

# %% [markdown]
# * Importar el primer fichero
# * Hacer un bucle para ir recorriendo todos los ficheros. Importante tener consistencia en el nombre
#   de los ficheros
# * Importamos los ficheros uno a uno
# * Cada fichero debe appendizarse al final del fichero anterior
# * Repetimos el bucle hasta que no queden ficheros

# %%
# Bucle para carga de 333 ficheros
filepath = ('F:/BD/GitHub/mlearningcourse/datasets/distributed-data/')

data = pd.read_csv('F:/BD/GitHub/mlearningcourse/datasets/distributed-data/001.csv')
final_length = len(data) #Para calcular la cantidad de filas 

for i in range (2, 333): #No considera el 333
    if i< 10 :
        filename = '00' +str(i)
    if 10 <= i <100 :
        filename = '0' +str(i)
    if i>=100 :
        filename = str(i)
    file = filepath + filename +'.csv'
    
    temp_data = pd.read_csv(file)
    final_length += (len(temp_data))
    
    data = pd.concat([data, temp_data], axis = 0)

# %%
#Variable para confirmar la cantidad de filas el data set construido
final_length
# Out:
# 772087

# %%
# Todas las filas cargadas en un solo dataset
data.shape
# Out:
# (772087, 4)

# %%
data.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
data.tail()
# Out:
#            Date  sulfate  nitrate   ID
# 726  2004-12-27      NaN      NaN  332
# 727  2004-12-28      NaN      NaN  332
# 728  2004-12-29      NaN      NaN  332
# 729  2004-12-30      NaN      NaN  332
# 730  2004-12-31      NaN      NaN  332

# %%
final_length == data.shape[0]
# Out:
# True

# %% [markdown]
# # Joins de datasets

# %%
filepath_med = ('F:/BD/GitHub/mlearningcourse/datasets/athletes/')

# %%
data_main = pd.read_csv(filepath_med + 'Medals.csv', encoding = 'ISO-8859-1')

# %%
data_main.head(1) #Primer dataset (medallas)
# Out:
#           Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0  Michael Phelps  23.0  2008            08/24/2008            8
#
#    Silver Medals  Bronze Medals  Total Medals
# 0              0              0             8

# %%
# Para saber la cantidad de únicos
atletas_unicos = data_main['Athlete'].unique().tolist()
print('Los atletas únicos son: '+ str (len(atletas_unicos)))
print('El listado de filas y columnas es: ') 
data_main.shape
# Out:
# Los atletas únicos son: 6956
# El listado de filas y columnas es:
# (8618, 8)

# %%
data_country = pd.read_csv(filepath_med + 'Athelete_Country_Map.csv', encoding = 'ISO-8859-1')

# %%
data_country.head() #Segundo dataset (Países)
# Out:
#             Athlete        Country
# 0    Michael Phelps  United States
# 1  Natalie Coughlin  United States
# 2     Aleksey Nemov         Russia
# 3     Alicia Coutts      Australia
# 4    Missy Franklin  United States

# %%
len(data_country)
# Out:
# 6970

# %%
#Hay más filas en el archivo de países, porque un jugador representó a dos países (ejemplo:)
data_country[data_country['Athlete']=='Aleksandar Ciric']
# Out:
#                Athlete                Country
# 1029  Aleksandar Ciric                 Serbia
# 1086  Aleksandar Ciric  Serbia and Montenegro

# %%
data_sports = pd.read_csv(filepath_med + 'Athelete_Sports_Map.csv', encoding = 'ISO-8859-1')

# %%
data_sports.head() #Tercer dataset
# Out:
#             Athlete       Sport
# 0    Michael Phelps    Swimming
# 1  Natalie Coughlin    Swimming
# 2     Aleksey Nemov  Gymnastics
# 3     Alicia Coutts    Swimming
# 4    Missy Franklin    Swimming

# %%
len(data_sports)  #Un mismo jugador pudo haber jugado en dos deportes olímpicos
# Out:
# 6975

# %%
# Buscamos los jugadores que se repiten
data_sports[(data_sports['Athlete']=='Chen Jing')      | 
            (data_sports['Athlete']=='Richard Thompson')|
            (data_sports['Athlete']=='Matt Ryan')]
# Out:
#                Athlete         Sport
# 528   Richard Thompson     Athletics
# 1308         Chen Jing    Volleyball
# 1419         Chen Jing  Table Tennis
# 2727         Matt Ryan        Rowing
# 5003         Matt Ryan    Equestrian
# 5691  Richard Thompson      Baseball

# %% [markdown]
# ## Uso de la función MERGE

# %% [markdown]
# ###  JOIN [Combina ambas tablas, duplica valores]

# %%
# Al quitar duplicados, el dataset elimina las duplicidades
data_country_dp = data_country.drop_duplicates(subset = 'Athlete')

# %%
len(data_country_dp) == len(atletas_unicos)
# Out:
# True

# %%
# Vamos a juntar dos data set
                            
data_main_country = pd.merge(  left = data_main       # Set de la izquierda
                             , right = data_country_dp   # Set de la derecha
                             , left_on = 'Athlete'    # Columna ID izquierda
                             , right_on = 'Athlete')  # Columna ID derecha

# %% [markdown]
#  ### Construímos el primer data set unido

# %%
data_main_country.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8  United States
# 1              0              2             8  United States
# 2              2              0             6  United States
# 3              2              3             6  United States
# 4              2              1             5  United States

# %%
data_main_country.shape
# Out:
# (8618, 9)

# %%
# Al no poner una condición en el JOIN, duplica todas las filas en las que aparece el registro (ejemplo con un jugador)
data_main_country[data_main_country['Athlete']=='Aleksandar Ciric']
# Out:
#                Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 1491  Aleksandar Ciric  30.0  2008            08/24/2008            0
# 1492  Aleksandar Ciric  26.0  2004            08/29/2004            0
# 1493  Aleksandar Ciric  22.0  2000            10/01/2000            0
#
#       Silver Medals  Bronze Medals  Total Medals Country
# 1491              0              1             1  Serbia
# 1492              1              0             1  Serbia
# 1493              0              1             1  Serbia

# %% [markdown]
# ### Unir la segunda tabla

# %%
data_sports_dp = data_sports.drop_duplicates(subset = 'Athlete')

# %%
len(data_sports_dp)
# Out:
# 6956

# %%
data_final = pd.merge(  left = data_main_country       # Set de la izquierda
                             , right = data_sports_dp   # Set de la derecha
                             , left_on = 'Athlete'    # Columna ID izquierda
                             , right_on = 'Athlete')  # Columna ID derecha

# %%
data_final.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country     Sport
# 0              0              0             8  United States  Swimming
# 1              0              2             8  United States  Swimming
# 2              2              0             6  United States  Swimming
# 3              2              3             6  United States  Swimming
# 4              2              1             5  United States  Swimming

# %% [markdown]
# # Tipos de Joins

# %%
#Para poder presentar imágenes
from IPython.display import Image
import numpy as np

# %% [markdown]
# ## Inner Join
# * Devuelve un data frame con las filas que tienen valor tanto en el primero como en el segundo data frame que estamos uniendo
# * El número de filas será igual al número de filas **comunes** que tengas ambos data sets
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     * Ambos comparten 30 filas
#     * Entonces A Inner Join B tendrá 30 filas
# * En términos de teoría de conjuntos, se trata de la intersección de los dos conjuntos

# %%
#Insertar imagen del Inner Join
Image(filename='F:/BD\GitHub/mlearningcourse/notebooks/resources/inner-join.png')

# %%
#Elegir 6 deportistas aleatoriamente
out_athletes = np.random.choice(data_main['Athlete'], size = 6, replace = False)
out_athletes
# Out:
# array(['Kaori Icho', 'Jess Schipper', 'Javier Mascherano',
#        'Darya Shkurikhina', 'Aldo Montano', 'Jeong Gyeong-Mi'],
#       dtype=object)

# %%
#deportistas que deseamos eliminar [para crear un data set sin 7 deportistas]
data_country_dlt = data_country_dp[(~data_country_dp['Athlete'].isin(out_athletes))&
                                  (data_country_dp['Athlete'] != 'Michael Phelps')]

data_sports_dlt = data_sports_dp[(~data_sports_dp['Athlete'].isin(out_athletes))&
                                  (data_sports_dp['Athlete'] != 'Michael Phelps')]

data_main_dlt = data_main[(~data_main['Athlete'].isin(out_athletes))&
                                  (data_main['Athlete'] != 'Michael Phelps')]

# %%
print( len(data_country_dlt))
print( len(data_sports_dlt))
print( len(data_mail_dlt))
# Out:
# 6949
# 6949
# 8603

# %%
# # data_main contiene toda la info
# data_country_dlt le falta la info de 7 atletas
merged_inner = pd.merge(left = data_main, right = data_country_dlt,
                       how = 'inner', left_on = 'Athlete', right_on = 'Athlete')
merged_inner.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0  Natalie Coughlin  25.0  2008            08/24/2008            1
# 1  Natalie Coughlin  21.0  2004            08/29/2004            2
# 2  Natalie Coughlin  29.0  2012            08/12/2012            0
# 3     Aleksey Nemov  24.0  2000            10/01/2000            2
# 4     Alicia Coutts  24.0  2012            08/12/2012            1
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              2              3             6  United States
# 1              2              1             5  United States
# 2              0              1             1  United States
# 3              1              3             6         Russia
# 4              3              1             5      Australia

# %%
len(merged_inner)
# Out:
# 8603

# %% [markdown]
# ## Left Join
# * Devuelve un data frame con las filas que tuvieran valor en el dataset de la izquierda, sin importar si tienen correspondencia en el de la derecha o no.
# * Las filas del data frame final que no correspondan a ninguna fila del data frame derecho, tendrán NAs en las columnas del data frame derecho.
# * El número de filas será igual al número de filas del data frame izquierdo
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Entonces A Left Join B tendrá 60 filas
# * En términos de teoría de conjuntos, se trata del propio data set de la izquierda quien, además tiene la intersección en su interior.

# %%
#Insertar imagen del Left Join
Image(filename='F:/BD\GitHub/mlearningcourse/notebooks/resources/left-join.png')

# %%
merged_left = pd.merge(left = data_main, right = data_country_dlt, 
                      how = "left", left_on = "Athlete", right_on = "Athlete")
len(merged_left)
# Out:
# 8618

# %%
merged_left.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8            NaN
# 1              0              2             8            NaN
# 2              2              0             6            NaN
# 3              2              3             6  United States
# 4              1              3             6         Russia

# %% [markdown]
# ## Right Join
# * Devuelve un data frame con las filas que tuvieran valor en el dataset de la derecha, sin importar si tienen correspondencia en el de la izquierda o no.
# * Las filas del data frame final que no correspondan a ninguna fila del data frame izquierdo, tendrán NAs en las columnas del data frame izquierdo.
# * El número de filas será igual al número de filas del data frame derecho
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Entonces A Right Join B tendrá 50 filas
# * En términos de teoría de conjuntos, se trata del propio data set de la derecha quien, además tiene la intersección en su interior.

# %%
#Insertar imagen del Right Join
Image(filename='F:/BD\GitHub/mlearningcourse/notebooks/resources/right-join.png')

# %%
merged_right = pd.merge(left = data_main_dlt, right = data_country_dp,
                       how = "right", left_on = "Athlete", right_on = "Athlete")
len(merged_right)
# Out:
# 8610

# %%
merged_right.tail(10)
# Out:
#                    Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 8600      Wietse van Alten  21.0  2000.0            10/01/2000          0.0
# 8601  Sandra Wagner-Sachse  31.0  2000.0            10/01/2000          0.0
# 8602             Rod White  23.0  2000.0            10/01/2000          0.0
# 8603        Michael Phelps   NaN     NaN                   NaN          NaN
# 8604         Jess Schipper   NaN     NaN                   NaN          NaN
# 8605          Aldo Montano   NaN     NaN                   NaN          NaN
# 8606            Kaori Icho   NaN     NaN                   NaN          NaN
# 8607     Darya Shkurikhina   NaN     NaN                   NaN          NaN
# 8608       Jeong Gyeong-Mi   NaN     NaN                   NaN          NaN
# 8609     Javier Mascherano   NaN     NaN                   NaN          NaN
#
#       Silver Medals  Bronze Medals  Total Medals        Country
# 8600            0.0            1.0           1.0    Netherlands
# 8601            0.0            1.0           1.0        Germany
# 8602            0.0            1.0           1.0  United States
# 8603            NaN            NaN           NaN  United States
# 8604            NaN            NaN           NaN      Australia
# 8605            NaN            NaN           NaN          Italy
# 8606            NaN            NaN           NaN          Japan
# 8607            NaN            NaN           NaN         Russia
# 8608            NaN            NaN           NaN    South Korea
# 8609            NaN            NaN           NaN      Argentina

# %% [markdown]
# ## Outer Join
# * Devuelve un data frame con todas las filas de ambos, reemplazando las ausencias de uno o de otro con NAs en la región específica..
# * Las filas del data frame final que no correspondan a ninguna fila del data frame derecho (o izquierdo), tendrán NAs en las columnas del data frame derecho (o izquierdo).
# * El número de filas será igual al máximo número de filas de ambos data frames
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Ambos comparten 30 filas
#     * Entonces A Outer Join B tendrá 60 + 50 - 30 = 80 filas
# * En términos de teoría de conjuntos, se trata de la unión de conjuntos.

# %%
#Insertar imagen del Right Join
Image(filename='F:/BD\GitHub/mlearningcourse/notebooks/resources/outer-join.png')

# %%
data_country_jb = data_country_dlt.append(
    {
        "Athlete": "Juan Gabriel Gomila",
        "Country": "España"
    },ignore_index = True
)

# %%
merged_outer = pd.merge(left = data_main, right=data_country_jb,
                       how = "outer", left_on = "Athlete", right_on="Athlete")
len(merged_outer)
# Out:
# 8619

# %%
merged_outer.head()
# Out:
#             Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008.0            08/24/2008          8.0
# 1    Michael Phelps  19.0  2004.0            08/29/2004          6.0
# 2    Michael Phelps  27.0  2012.0            08/12/2012          4.0
# 3  Natalie Coughlin  25.0  2008.0            08/24/2008          1.0
# 4  Natalie Coughlin  21.0  2004.0            08/29/2004          2.0
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0            0.0            0.0           8.0            NaN
# 1            0.0            2.0           8.0            NaN
# 2            2.0            0.0           6.0            NaN
# 3            2.0            3.0           6.0  United States
# 4            2.0            1.0           5.0  United States

# %%
merged_outer.tail()
# Out:
#                    Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 8614      Kateryna Serdiuk  17.0  2000.0            10/01/2000          0.0
# 8615      Wietse van Alten  21.0  2000.0            10/01/2000          0.0
# 8616  Sandra Wagner-Sachse  31.0  2000.0            10/01/2000          0.0
# 8617             Rod White  23.0  2000.0            10/01/2000          0.0
# 8618   Juan Gabriel Gomila   NaN     NaN                   NaN          NaN
#
#       Silver Medals  Bronze Medals  Total Medals        Country
# 8614            1.0            0.0           1.0        Ukraine
# 8615            0.0            1.0           1.0    Netherlands
# 8616            0.0            1.0           1.0        Germany
# 8617            0.0            1.0           1.0  United States
# 8618            NaN            NaN           NaN         España

# %%
len(data_main)
# Out:
# 8618

# %%
len(data_main_dlt)
# Out:
# 8603

# %%
len(data_country_dp)
# Out:
# 6956

# %%
len(data_country_dlt)
# Out:
# 6949

# %%
len(merged_inner)
# Out:
# 8603

# %%
len(merged_left)
# Out:
# 8618

# %%
len(merged_right)
# Out:
# 8610

# %%
len(merged_outer)
# Out:
# 8619
